# %% [markdown]
# # Getting Started with Gradio
#
# Gradio is an open-source Python library that makes it easy to build and share beautiful, customizable web demos of your machine learning models, APIs, and data science workflows. It's perfect for quickly showcasing your work without needing to know HTML, CSS, or JavaScript.
#
# This document will cover the essential building blocks of Gradio and provide code examples to get you started.
#
# ## Installation
#
# First, you need to install the Gradio library. You can do this using pip for local machines:

# %%
#gr is a lib to build UIs
#two major ways:

#1. gr.Interface: more abstract (hides away details), less control/customization
#2. gr.Blocks: when we want more control/customization, more complex ui's

# %%
# %pip install gradio --quiet

# %% [markdown]
# ## The Core Concept: `gradio.Interface`
#
# The central class in Gradio is `gradio.Interface`. It takes a Python function, and automatically generates a user interface around it.
#
# You need to specify three main things when creating an `Interface`:
#
# 1.  **`fn`**: The Python function that takes inputs and returns outputs.
# 2.  **`inputs`**: The Gradio component(s) that define the input type(s) for your function.
# 3.  **`outputs`**: The Gradio component(s) that define the output type(s) of your function.
#
# Let's start with a simple example: a function that takes a name as input and returns a greeting.

# %%
import gradio as gr

def greet(name):
    #pipe = pipeline("text-generation", model="gpt2")
    #return pipe(name)
    return "Hello, " + name + "!!!!"


demo = gr.Interface(fn=greet, inputs="text", outputs="text")


demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://71189808322640fb73.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://71189808322640fb73.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
import gradio as gr

def greet_with_age(name: str, age: int) -> str:
    return f"Hello, {name}! You are {age} years old."

# Inputs as a list: [textbox for name, number input for age]
demo = gr.Interface(fn=greet_with_age, inputs=["text", "number"], outputs="text")

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://5d48e19ca6756aab90.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5d48e19ca6756aab90.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# exercise : first try out this example
# exercise: try to return 3 and 1 output(s) out of analyze_text


import gradio as gr

def analyze_text(text):
    word_count = len(text.split())
    char_count = len(text)
    return f"Word Count: {word_count}", f"Character Count: {char_count}"

# Outputs as a list: [textbox for word count, textbox for character count]
demo = gr.Interface(fn=analyze_text, inputs="text", outputs=["text", "text"])

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://0c41e5e1d0c68f2d19.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0c41e5e1d0c68f2d19.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# **Note:** We've commented out `demo.launch()` in the code cell above so that the notebook doesn't automatically start a Gradio app when you run the cell. When you are ready to test your Gradio app locally, uncomment that line and run the cell.
#
# ## Input and Output Components
#
# Gradio provides a wide variety of components for both inputs and outputs. Here are some common ones:
#
# ### Text
#
# *   **`gr.Textbox()`**: For single or multi-line text input/output.
# *   **`gr.Label()`**: For displaying a classification label and confidence scores.
#
# ### Numbers
#
# *   **`gr.Number()`**: For numerical input.
# *   **`gr.Slider()`**: For numerical input within a specified range.
#
# ### Media
#
# *   **`gr.Image()`**: For image input/output (upload, webcam, or gallery).
# *   **`gr.Audio()`**: For audio input/output (microphone or file upload).
# *   **`gr.Video()`**: For video input/output.
#
# ### Data Structures
#
# *   **`gr.DataFrame()`**: For displaying tabular data.
# *   **`gr.JSON()`**: For displaying JSON data.
#
# ### Other
#
# *   **`gr.Dropdown()`**: For selecting an option from a list.
# *   **`gr.Checkbox()`**: For boolean input.
# *   **`gr.Radio()`**: For selecting one option from a set.
# *   **`gr.File()`**: For file uploads.
#
# You can pass instances of these components to the `inputs` and `outputs` parameters. If you have multiple inputs or outputs, pass them as a list.
#
# Let's look at an example with multiple inputs:

# %% [markdown]
# Let's understand some of the Gradio components piece by piece.
#
# ### Textbox Input and Output

# %%
import gradio as gr

def echo_text(text):
    return text

demo_textbox = gr.Interface(
    fn=echo_text,
    inputs=gr.Textbox(label="Enter some text"), # "text"
    outputs=gr.Textbox(label="Echoed text"), # "text"
    title="Textbox Example"
)

demo_textbox.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://4f6ff16bbfa26a46ec.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4f6ff16bbfa26a46ec.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Number Input and Output

# %%
import gradio as gr

def double_number(number):
    return number * 2

demo_number = gr.Interface(
    fn=double_number,
    inputs=gr.Number(label="Enter a number"),
    outputs=gr.Number(label="Doubled number"),
    title="Number Example"
)

demo_number.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ac41a5bde075cbcf5f.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ac41a5bde075cbcf5f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Slider Input and Number Output

# %%
import gradio as gr

def add_ten(value):
    return value + 10

demo_slider = gr.Interface(
    fn=add_ten,
    inputs=gr.Slider(minimum=0, maximum=100, label="Select a value"),
    outputs=gr.Number(label="Value + 10"),
    # exercise todo: fill here

)

demo_slider.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://d874a3845a2b93225a.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://d874a3845a2b93225a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Checkbox Input and Text Output

# %%
import gradio as gr

def check_status(is_checked):
    return f"Checkbox is {'checked' if is_checked else 'unchecked'}"

demo_checkbox = gr.Interface(
    fn=check_status,
    inputs=gr.Checkbox(label="Check the following box"),
    outputs=gr.Textbox(label="Status"),
    title="Checkbox Example"
)

demo_checkbox.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://321ecd5e48cc0d349f.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://321ecd5e48cc0d349f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Dropdown Input and Text Output

# %%
import gradio as gr

def show_choice(choice):
    return f"You selected: {choice}"

demo_dropdown = gr.Interface(
    fn=show_choice,
    inputs=gr.Dropdown(["Option A", "Option C", "Option B"], label="Choose an option"),
    outputs=gr.Textbox(label="Your choice"),
    title="Dropdown Example"
)

demo_dropdown.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://e6b50defed29dfc8e6.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://e6b50defed29dfc8e6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ### Image Input and Output

# %%
import gradio as gr

def process_image(image):
    # homework: process the image using an ml model and generate a caption
    # In a real application, you would process the image here
    # For this example, we just return the image

    # how to generate captions corresp to images
    # exercise: <model> to generate caption corresp to image
    # return that caption
    # return caption
    return image

demo_image = gr.Interface(
    fn=process_image,
    inputs=gr.Image(label="Upload an image"),
    outputs=gr.Image(label="Processed image"), # gr.Textbox
    title="Image Example"
)

demo_image.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://34e3d3f00aac509980.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://34e3d3f00aac509980.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# And an example with multiple outputs:

# %% [markdown]
# ## Customizing Components
#
# Gradio components can be customized using various parameters during initialization. For example, you can set labels, default values, and appearance.

# %%
import gradio as gr

def greet_custom(name):
    return "Hello, " + name + "!"

demo = gr.Interface(
    fn=greet_custom,
    inputs=gr.Textbox(label="Enter Your Name", placeholder="Type here for some greeting...", lines=5),
    outputs=gr.Textbox(label="Greeting Output"),
    title="Customized Greeting App"
)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://657633da350505ce97.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://657633da350505ce97.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Sharing Your Gradio App
#
# Gradio makes it easy to share your demos. When you use `launch()`, you get a local URL. You can also set `share=True` to create a public, shareable link that is valid for 72 hours.

# %%
import gradio as gr

def greet(name):
    return "Hello, " + name + "!"

with gr.Blocks() as demo:
  with gr.Row():
    name = gr.Textbox(label="enter the name here")
    output = gr.Textbox(label="here's your output")
  with gr.Row():
    greet_btn = gr.Button("Click Me")

    greet_btn.click(fn=greet, inputs=name, outputs=output)

# To create a shareable link (valid for 72 hours)
demo.launch(share=True)
